# %%
import pandas as pd
pd.set_option('max_columns',None)
reviews=pd.read_csv("/home/saumitra/Desktop/kaggle/winemag-data_first150k.csv",index_col=0)
reviews.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
reviews['points'].value_counts().sort_index().plot.bar()

# %% [markdown]
# **Adjusting the size of the figure diplayed**

# %%
reviews['points'].value_counts().sort_index().plot.bar(figsize=(12,6))

# %% [markdown]
# **Color**

# %%
reviews['points'].value_counts().sort_index().plot.bar(figsize=(12,6), color='mediumvioletred')

# %% [markdown]
# **Adjusting fonts for the labels**

# %%
reviews['points'].value_counts().sort_index().plot.bar(figsize=(12,6), color='mediumvioletred', fontsize=16)

# %% [markdown]
# **Title**

# %%
reviews['points'].value_counts().sort_index().plot.bar(figsize=(12,6), color='mediumvioletred', fontsize=16, 
                                                       title='Rankings given by wine Magazine')

# %% [markdown]
# However, this title is too small. Unfortunately, pandas doesn't give us an easy way of adjusting the title size.
#
# Under the hood, pandas data visualization tools are built on top of another, lower-level graphics library called
# matplotlib. Anything that you build in pandas can be built using matplotlib directly. pandas merely make it easier
# to get that work done.
#
# matplotlib does provide a way of adjusting the title size. Let's go ahead and do it that way, and see what's
# different:

# %%
import matplotlib.pyplot as plt
ax=reviews['points'].value_counts().sort_index().plot.bar(figsize=(12,6), color='mediumvioletred', fontsize=16)
ax.set_title("Rankings given by wine magazine", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Rankings given by wine magazine')

# %% [markdown]
# The ax.set_title method makes easy to change the fontsize;the title keyword parameter in pandas library does not.
#
# seaborn, covered in a separate section of the tutorial, also uses matplotlib under the hood. This means that the
# tricks above work there too. seaborn has its own tricks, too—for example we can use the very convenient .
# sns.despine method to turn off the ugly black border.

# %%
import seaborn as sns
ax=reviews['points'].value_counts().sort_index().plot.bar(figsize=(12,6), color='mediumvioletred', fontsize=16)
ax.set_title("Rankings given by wine magazine", fontsize=20)
sns.despine(bottom=True,left=True)

# %%
pokemon=pd.read_csv("/home/saumitra/Desktop/kaggle/pokemon.csv")
pokemon.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  against_grass  against_ground  against_ice  \
# ...

# %%
pokemon.plot.scatter(x='attack',y='defense',figsize=(12,6),title='pokemon by Attack and Defense')

# %%
ax=pokemon['base_total'].plot.hist(bins=50,figsize=(12,6),fontsize=16,color='gray')
ax.set_title("Pokemon by Stat Total",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pokemon by Stat Total')

# %%
ax=pokemon['type1'].value_counts().plot.bar(figsize=(12,6),color='darkblue',fontsize=14)
ax.set_title("Pokemon by Primary Type",fontsize=20)
sns.despine(bottom=True,left=True)
