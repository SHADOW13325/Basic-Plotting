# %%
import pandas as pd
reviews=pd.read_csv("/home/saumitra/Desktop/kaggle/winemag-data_first150k.csv")
import seaborn as sns
reviews.head(3)
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
#
#          region_1 region_2             variety                   winery
# 0     Napa Valley     Napa  Cabernet Sauvignon                    Heitz
# 1            Toro      NaN       Tinta de Toro  Bodega Carmen Rodríguez
# 2  Knights Valley   Sonoma     Sauvignon Blanc                 Macauley

# %% [markdown]
# Subplotting is a technique for creating multiple plots that live side-by-side in one overall figure. We can use
# the subplots method to create a figure with multiple subplots. subplots takes two arguments. The first one
# controls the number of rows, the second one the number of columns.

# %%
import matplotlib.pyplot as plt
fig,axarr=plt.subplots(2,1,figsize=(12,8))

# %% [markdown]
# Let's break this down a bit. When pandas generates a bar chart, behind the scenes here is what it actually does:
#
# 1. Generate a new matplotlib Figure object.
# 2. Create a new matplotlib AxesSubplot object, and assign it to the Figure.
# 3. Use AxesSubplot methods to draw the information on the screen.
# 4. Return the result to the user.
#
# In a similar way, our subplots operation above created one overall Figure with two AxesSubplots vertically nested
# inside of it.
#
# subplots returns two things, a figure (which we assigned to fig) and an array of the axes contained therein
# (which we assigned to axarr). Here are the axarr contents:

# %%
axarr
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f0cedc90438>,
# ...
#       dtype=object)

# %% [markdown]
# To tell pandas which subplot we want a new plot to go in—the first one or the second one—we need to grab the
# proper axis out of the list and pass it into pandas via the ax parameter:

# %%
fig,axarr=plt.subplots(2,1,figsize=(12,6))
reviews['points'].value_counts().sort_index().plot.bar(ax=axarr[0])
reviews['province'].value_counts().head(20).plot.bar(ax=axarr[1])

# %%
fig,axarr=plt.subplots(2,2,figsize=(12,8))

# %%
#axis array becomes list of rows
axarr
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0ce9ee64e0>,
# ...
#       dtype=object)

# %%
fig,axarr=plt.subplots(2,2,figsize=(12,8))
reviews['points'].value_counts().sort_index().plot.bar(ax=axarr[0][0])
reviews['province'].value_counts().head(20).plot.bar(ax=axarr[1][1])

# %%
fig,axarr=plt.subplots(2,2,figsize=(12,8))
axe=reviews['points'].value_counts().sort_index().plot.bar(ax=axarr[0][0],color='mediumvioletred',fontsize=14)
axe.set_title("Wine Scores",fontsize=20)
axe=reviews['price'].value_counts().plot.hist(ax=axarr[0][1],color='mediumvioletred',fontsize=14)
axe.set_title("Wine Prices",fontsize=20)
axe=reviews['variety'].value_counts().head(20).plot.bar(ax=axarr[1][0],color="mediumvioletred",fontsize=14)
axe.set_title("Wine varities",fontsize=20)
axe=reviews['province'].value_counts().head(20).plot.bar(ax=axarr[1][1],color="mediumvioletred",fontsize=14)
axe.set_title("Wine Origin",fontsize=20)
plt.subplots_adjust(hspace=.3)
sns.despine()

# %%
pokemon=pd.read_csv("/home/saumitra/Desktop/kaggle/pokemon.csv")
pokemon.head(3)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
#
#    against_flying  against_ghost      ...       percentage_male  \
# 0             2.0            1.0      ...                  88.1
# 1             2.0            1.0      ...                  88.1
# 2             2.0            1.0      ...                  88.1
#
#    pokedex_number  sp_attack  sp_defense  speed  type1   type2  weight_kg  \
# ...

# %%
fig,axarr=plt.subplots(2,1,figsize=(8,8))

# %%
fig,axarr=plt.subplots(2,1,figsize=(8,8))
pokemon['attack'].plot.hist(ax=axarr[0])
axarr[0].set_title("Pokemon Attack Ratings",fontsize=20)
pokemon['defense'].plot.hist(ax=axarr[1])
axarr[1].set_title("Pokemon Defense Ratings",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pokemon Defense Ratings')
